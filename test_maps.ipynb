# %%
from pre_summer_work.plot_maps import plot_dist_emissions

# %%
plot_dist_emissions("inputs/dist_weighted_mat_generated_nc_2020.nc")
# Out:
# /Users/abhigyanprakash/Desktop/supaero skool stuff/Research project/prelim_code/pre_summer_work/plot_maps.py:117: RuntimeWarning: divide by zero encountered in log10
#   plot = ax.pcolormesh(lon_grid, lat_grid, np.log10(dist_latlon), cmap='plasma', shading='auto', transform=ccrs.PlateCarree())

# %%
plot_dist_emissions("inputs/mat_generated_nc_2020.nc")
# Out:
# /Users/abhigyanprakash/Desktop/supaero skool stuff/Research project/prelim_code/pre_summer_work/plot_maps.py:117: RuntimeWarning: divide by zero encountered in log10
#   plot = ax.pcolormesh(lon_grid, lat_grid, np.log10(dist_latlon), cmap='plasma', shading='auto', transform=ccrs.PlateCarree())
