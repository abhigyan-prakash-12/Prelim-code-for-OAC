# %% [markdown]
# # netCDF Sample run 1- single coordinate plots
# This Jupyter notebook is to show the plots made using netCDF files with aviation emission data.\
# the emission inventories used in this repositroy come from the DLR project \cite{}\
# This notebooks focusing on plotting emissions with respect to single coordinate values.

# %%
from plot_single_coord import plot_alt, plot_alt_thresh, plot_co2_nox_ratio, plot_lat, plot_lat_alt, plot_lon, plot_pres

# %%
plot_alt("Inventories/emi_inv_2020.nc",'km',sp1=1, sp2=1,sp3=1)
plot_alt("Inventories/emi_inv_2020.nc",'ft',sp1=1, sp2=1,sp3=1)

# %%
plot_pres("Inventories/emi_inv_2020.nc",sp1=1, sp2=1,sp3=1)

# %%
plot_co2_nox_ratio("Inventories/emi_inv_2020.nc")

# %%
from runncdf import plot_alt_threshog
plot_alt_threshog("Inventories/emi_inv_2025.nc", thresh = 11, unit="km", mode="above", sp1=1)
plot_alt_thresh("Inventories/emi_inv_2025.nc", thresh = 11, unit="km", mode="above", sp1=1)

# %%
plot_lat("Inventories/emi_inv_2020.nc",sp1=1, sp2=None,sp3=1)
plot_lat("Inventories/emi_inv_2020.nc",sp1=None, sp2=1,sp3=None)

# %%
plot_lon("Inventories/emi_inv_2020.nc",sp1=1, sp2=None,sp3=1)
plot_lon("Inventories/emi_inv_2020.nc",sp1=None, sp2=1,sp3=None)

# %%
plot_lat_alt("Inventories/emi_inv_2025.nc", unit = 'm')
